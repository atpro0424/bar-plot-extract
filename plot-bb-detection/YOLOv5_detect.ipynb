# %%
from google.colab import drive
drive.mount('/content/drive')
! pip install -q kaggle
from google.colab import files
files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle competitions download -c benetech-making-graphs-accessible
! mkdir data
! unzip -q benetech-making-graphs-accessible.zip -d data
# Out:
# Mounted at /content/drive
#      <input type="file" id="files-bb01b561-d765-4c5c-9bab-5f70a3131b0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb01b561-d765-4c5c-9bab-5f70a3131b0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !git clone https://github.com/atpro0424/yolov5-bbox.git
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-147-gaa7c45c Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.9/166.8 GB disk)

# %%
# !python detect.py --source /content/data/train/images --weights /content/yolov5-bbox/best.pt
# Out:
# Streaming output truncated to the last 5000 lines.
# image 55581/60578 /content/data/train/images/eaedb251e670.jpg: 384x640 1 Chart, 5.0ms
# image 55582/60578 /content/data/train/images/eaeead418936.jpg: 480x640 2 Charts, 5.4ms
# image 55583/60578 /content/data/train/images/eaeeb1c2ecdd.jpg: 384x640 1 Chart, 8.2ms
# image 55584/60578 /content/data/train/images/eaef70ba842d.jpg: 416x640 1 Chart, 7.8ms
# image 55585/60578 /content/data/train/images/eaf036991cb3.jpg: 352x640 1 Chart, 9.5ms
# image 55586/60578 /content/data/train/images/eaf06e9e07db.jpg: 448x640 1 Chart, 5.3ms
# image 55587/60578 /content/data/train/images/eaf20f7d8945.jpg: 480x640 1 Chart, 5.4ms
# image 55588/60578 /content/data/train/images/eaf3a9a87868.jpg: 384x640 1 Chart, 5.2ms
# image 55589/60578 /content/data/train/images/eaf3d05d20a6.jpg: 416x640 1 Chart, 7.3ms
# image 55590/60578 /content/data/train/images/eaf3d24fb032.jpg: 384x640 1 Chart, 5.6ms
# ...
